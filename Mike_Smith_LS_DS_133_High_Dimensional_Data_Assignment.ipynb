# %% [markdown]
# <a href="https://colab.research.google.com/github/gomlfx/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/Mike_Smith_LS_DS_133_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
plt.rcParams.update({'font.size':14})

# %%
#passes vertical line test
x = np.arange(-10, 11)
y = x**3 + 2*x
plt.plot(x,y)
plt.axvline(x=0, color='r');

# %%
x = np.arange(-2,2)
y = 2*x + 3
plt.plot(y)
plt.axvline(x=2, color='r');

# %%
#doesn't pass vertical line test
y = np.arange(-10,11)
x = y**4 + 2*y
plt.plot(x,y)
plt.axvline(x=2000, color='r')

# %%
theta = np.arange(0, 8*np.pi, 0.1)

for c in np.arange(0,1):
  x = 1*np.cos(theta + c)*np.exp(.2*theta)
  y = 1*np.sin(theta + c)*np.exp(.2*theta)
  p1 = plt.plot(x,y)
plt.axvline(x = .5, color = 'r');

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# 1.   A function can't have the same input (x) mapped to multiple outputs (y).

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %%
#In any given array, any x mapped to more than one y is not a function. Relation 2 is the only function.

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
# dimensionality of the doman and codomain is determined by the number of tuples. m domain = 3, codomain = 3.
# n domain = 4, codomain = 2.

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
#yes, the very practice of isolating one input to one output in a function is a prerequisite to
#map higher dimensional space to a lower dimensional space.

# %%
#An example of 2D down to 1D. The red slant represents 2D. The blue line 1D. The interection of red/blue dot is the 2D to 1D mapping.
# = dimensionality reduction = PCA

# %%
#plot the function g(x1, x2) = x1 + x2
def g(z):
  return z[0] + z[1]

#define some fake points
x = []
y = [4,4,4,4]
points = [(2,4), (3,5), (4,6), (5,7)]

# %%
#apply and plot function
for point in points:
  plt.scatter(y=point[0], x=point[1], c='r')
  x.append(g(point))
print(x)
plt.scatter(x, y);
# Out:
# [6, 8, 10, 12]

# %%
#An example of 3D down to 2D. The red slant represents 3D. The blue line 2D. The interection of red/blue dot is the 3D to 2D mapping.
#use tuples (orderd lists)
def h(z): 
  return z[0] + 2, z[1] - z[2]

# %%
#create some fake data
x = []
y = []
points = [(20,30,5), (30,40,10), (40,50,15)]

# %%
#plot the function
#show the inputs
for point in points:
  plt.scatter(x=point[0],
              y=point[1],
              s=point[2]**3, #size representing the 3rd dimension
              c='r'); 
  x.append(h(point)[0])
  y.append(h(point)[1])
#show the outputs
print(x,y)
plt.scatter(x,y,s=100);
# Out:
# [22, 32, 42] [25, 30, 35]

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
#p
def p(vect):
  x1 = vect[0][0]
  x2 = vect[1][0]
  output_row1 = np.array([x1 + 3*x2])
  output_row2 = np.array([2*x2 - x1])
  output_vector = np.array([output_row1, output_row2])
  return output_vector

# %%
#output vector
i_hat = np.array([[1],[0]])
a = p(i_hat)

# %%
#output vector
j_hat = np.array([[0],[1]])
b = p(j_hat)

# %%
#transformation vector
#turn those into a matrix, notice np trick for combining column vectors.
T2 = np.column_stack([a,b])
T2
# Out:
# array([[ 1,  3],
#        [-1,  2]])

# %%
#import to dataframe
pd.DataFrame(T2)
# Out:
#    0  1
# 0  1  3
# 1 -1  2

# %%
#q
def q(vect):
  x1 = vect[0][0]
  x2 = vect[1][0]
  x3 = vect[2][0]
  output_row1 = np.array([4*x1 + x2 + 2*x3])
  output_row2 = np.array([2*x2 - x1 + 3*x3])
  output_row3 = np.array([5*x1 - 2*x3 + x2])
  output_vector = np.array([output_row1, output_row2, output_row3])
  return output_vector

# %%
#output vector
i_hat = np.array([[1],[0],[0]])
a = q(i_hat)

# %%
#output vector
j_hat = np.array([[0],[1],[0]])
b = q(j_hat)

# %%
k_hat = np.array([[0],[0],[1]])
c = q(k_hat)

# %%
#transformation vector
#turn those into a matrix, notice np trick for combining column vectors.
T3 = np.column_stack([a,b,c])
T3
# Out:
# array([[ 4,  1,  2],
#        [-1,  2,  3],
#        [ 5,  1, -2]])

# %%
#import to dataframe
pd.DataFrame(T3)
# Out:
#    0  1  2
# 0  4  1  2
# 1 -1  2  3
# 2  5  1 -2

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
#use original function again to find the value of passing in one possible vector
input_vector = np.array([[3],[4]])
p(input_vector)
# Out:
# array([[15],
#        [ 5]])

# %%
#get exactly the same result using matrix multiplication (transformation matrix)
#proves using trans matrix (np.matmul(T,...)) is same as using def p(vect):
output_vector = np.matmul(T2, input_vector) 
output_vector
# Out:
# array([[15],
#        [ 5]])

# %%
#q function
input_vector = np.array([[3],[4],[5]])
q(input_vector)
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %%
#q transformation matrix
output_vector = np.matmul(T3, input_vector) 
output_vector
# Out:
# array([[26],
#        [20],
#        [ 9]])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %%
#Eigenvectors (vector) never change their direction. Eigenvalue is the scale (scalar) that the eigenvector was scaled to. 
#Together, they can describe any other vector in that same dimensional space. 
#This in turn is used for PCA (principal component analysis), a tool for dimensionality reduction (column reduction in a dataset).
#Finding eigenvectors/eigenvalues involves matrix diagonalization, which in turn is PCA.
#1:32:55 / 2:44:42

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %%
#visualization for one, hard to visualize 3d on 2d, harder for >3d. 
#https://seaborn.pydata.org/_images/seaborn-pairplot-1.png 1000 columns and 1 scatter plot for each column?
#Redundancy = diminishing return = risk of using greater and greater number of columns. = Cost effectiveness
#Increased computational workload. The difficulty of searching through a space gets exponentially harder.
#Sparcity of data, due to exponentially increased search space. This can lead to the model to approximate datapoints equidistant.
#Overfitting when P begins to approach N. (This is an unimaginably terrible situation would never happen with my currency datasets).

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %%
#P >= N
#P is number of columns (features), and N is number of rows (observations)
#Ideally N = 5P
#more data in terms of additional dimensions is diminishing value, so PCA.
#get more observations not more features

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.sample(5)
# Out:
# (64535, 99)
#               CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 39874  '589356350145'    34    '2'  ...    '3 50% or More'       '-5'       '-5'
# 36810  '572926300148'    62    '1'  ...  '1 Less than 30%'       '-5'       '-5'
# 17840  '300504230103'    42    '2'  ...  '1 Less than 30%'       '-5'       '-5'
# 57952  '999900011838'    69    '2'  ...     '2 30% to 50%'       '-5'       '-5'
# 42299  '599517800148'    80    '3'  ...  '1 Less than 30%'     'West'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.sample(5)
# Out:
# (64535, 99)
#        CONTROL  AGE1  METRO3  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 10384    10384    44       1  ...          1          0          0
# 10912    10912    32       0  ...          1          0          0
# 40582    40582    63       0  ...          3          0          0
# 57351    57351    17       0  ...          3          0          0
# 7370      7370    61       2  ...          1          0          0
#
# [5 rows x 99 columns]

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
### Your Code Here
#import libraries
from numpy import array
#from sklearn.preprocessing import StandardScalar
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

#2:11:35 / 2:44:42
#standardize (mean = 0, std = 1)
#variance-covariance
#eigenvector
#matrix transformation (PCA)

# %%
#we want PCA of 2 different datasets: PC1 (national), and PC2 (national_processed)
#visualize a little of the 2 datasets
PC1 = national
PC2 = national_processed

# %%
#2d
#Purple=0,Yellow=1
plt.scatter(x=PC2['AGE1'],
            y=PC2['VALUE'],
            c=PC2['OWNRENT'],
            alpha=.5)
plt.xlabel('AGE1')
plt.ylabel('VALUE')
# Out:
# Text(0, 0.5, 'VALUE')

# %%
#3d
plt.figure().gca(projection='3d')
plt.scatter(PC2['VALUE'],
            PC2['AGE1'],
            PC2['ROOMS'],
            c=PC2['OWNRENT'],
            alpha=.5)
plt.xlabel('VALUE')
plt.ylabel('AGE1')
# Out:
# Text(0.5, 0, 'AGE1')

# %%
plt.scatter(x=PC2['VALUE'],
            y=PC2['AGE1'],
            c=PC2['ROOMS'],
            alpha=.5)
plt.xlabel('VALUE')
plt.ylabel('AGE1')
# Out:
# Text(0, 0.5, 'AGE1')

# %%
#the charts don't look quite right but enough with playing with charts. 
#Let's check if our data is standardized and get the PCA for PC1,PC2.
#import StandardScaler
from sklearn.preprocessing import StandardScaler
feature_cols=PC2.columns[1:]
feature_cols[:5]
# Out:
# Index(['AGE1', 'METRO3', 'REGION', 'LMED', 'FMR'], dtype='object')

# %%
x = PC2.loc[:, feature_cols].values
x = StandardScaler().fit_transform(x)

# %%
#check whether the data is normalized
print('{:.2f}'.format(np.mean(x)))
np.std(x)
# Out:
# 0.00
# 0.9948848769417227

# %%
#convert the normalized feature into a dataframe
normal = pd.DataFrame(x,columns=feature_cols)
print(normal.shape)
normal.sample(15)
# Out:
# (64535, 98)
#            AGE1    METRO3    REGION  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 45714  0.569809 -0.966702  0.576698  ...  -0.544709  -0.462107        0.0
# 53579  1.225713 -0.178959  0.576698  ...   2.737836  -0.462107        0.0
# 19462 -0.785726 -0.178959  1.528983  ...   1.643655   2.164001        0.0
# 59162  0.307447 -0.966702  0.576698  ...   1.643655  -0.462107        0.0
# 34905  0.438628 -0.178959  1.528983  ...   0.549473   2.164001        0.0
# 22365  0.875897  1.396527 -0.375587  ...  -0.544709  -0.462107        0.0
# 54936 -0.916907 -0.178959  0.576698  ...  -0.544709  -0.462107        0.0
# 47354 -1.222996 -0.966702 -0.375587  ...  -0.544709  -0.462107        0.0
# 57634  1.356894 -0.178959  0.576698  ...   0.549473  -0.462107        0.0
# 13002  0.351174 -0.178959 -0.375587  ...  -0.544709  -0.462107        0.0
# 39177  0.351174 -0.178959  1.528983  ...  -0.544709   2.164001        0.0
# ...

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
