# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobpad/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/module3-dimensionality-reduction/LS_DS12_133A_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import matplotlib.pyplot as plt

# vectors
v1 = [3,2]
v2 = [2,3]

# plot the vectors
plt.arrow(2,3,v1[0],v1[1],head_width=.0,head_length=.0,color='red')
plt.arrow(0,0,v2[0],v2[1],head_width=.0,head_length=.0,color='red')

plt.xlim(-1,6)
plt.ylim(-1,6)
plt.title('PASSES THE VERTICAL LINE TEST');

# %%
# vectors
v1 = [4,2]
v2 = [2,3]

# plot the vectors
plt.arrow(0,2,v1[0],v1[1],head_width=.0,head_length=.0,color='red')
plt.arrow(0,0,v2[0],v2[1],head_width=.0,head_length=.0,color='red')

plt.xlim(-1,6)
plt.ylim(-1,6)
plt.title('FAILS THE VERTICAL LINE TEST');

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %%
# First, what makes a function a function?

# If the input of "X" produces two outputs of "Y", it's not a function,
#   and vice versa
# Because of the redundency in the "X" axis. "X" can't be on the same "Y"
#   at the same time

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %%
# Relation 2 is the only one that's a function
#  because it's the (x,y) "X"'s are all different

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 For the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
# Count the commas and add 1
# m = 3:3 
# n = 4:2

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
# I don't think it's possible, (at least with my current understanding)
#   for a function to have the capability to increase its dimensionality

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %% [markdown]
# --------------------------------------
# Step 1 for p
# \begin{align}
# \\p(
# \begin{bmatrix} 1 \\ 0 \end{bmatrix}) = \begin{bmatrix} 1 \\ -1 \end{bmatrix}
# \end{align}
#
# Step 2 for p
# \begin{align}
# \\p(
# \begin{bmatrix} 0 \\ 1 \end{bmatrix}) = \begin{bmatrix} 3 \\ 2 \end{bmatrix}
# \end{align}
#
# Step 3 for p
# \begin{align}
# \\T =
# \begin{bmatrix} 1\\-1 \end{bmatrix}
# \begin{bmatrix} 3\\2 \end{bmatrix}
# \end{align}
#
# ------------------------
# Step 1 for q
# \begin{align}
# \\q = (
# \begin{bmatrix} 1\\0\\0 \end{bmatrix}) =
# \begin{bmatrix} 4\\-1\\5 \end{bmatrix}
# \end{align}
#
# Step 2 for q
# \begin{align}
# \\q = (
# \begin{bmatrix} 0\\1\\0 \end{bmatrix}) =
# \begin{bmatrix} 1\\2\\1 \end{bmatrix}
# \end{align}
#
# Step 3 for q
# \begin{align}
# \\q = (
# \begin{bmatrix} 0\\0\\1 \end{bmatrix}) =
# \begin{bmatrix} 2\\3\\-2 \end{bmatrix}
# \end{align}
#
# Step 3 for q
# \begin{align}
# \\T =
# \begin{bmatrix}
#  4 & 1 & 2\\
# -1 & 2 & 3\\
#  5 & 1 & -2
# \end{bmatrix}
# \end{align}

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %% [markdown]
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \end{align}

# %%
import numpy as np
# input matrix (3,4)
a_input_matrix = ([3,4])
a_inp_matrix = np.array(a_input_matrix)

x1 = a_inp_matrix[0] + (3 * a_inp_matrix[1])
x2 = (2 * a_inp_matrix[1]) - a_inp_matrix[0]
print(x1, x2)
# Out:
# 15 5

# %%
tm = ([[1,3],[-1,2]])
tm = np.array(tm)
tm.T
# Out:
# array([[ 1, -1],
#        [ 3,  2]])

# %%
abc = np.dot(a_inp_matrix, tm.T)
abc
# Out:
# array([15,  5])

# %% [markdown]
# \begin{align}
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
b_input_matrix = ([3,4,5])
b_inp_matrix = np.array(b_input_matrix)

x = b_inp_matrix[0]
y = b_inp_matrix[1]
z = b_inp_matrix[2]

x1 = (4*x)+y+(2*z)
y1 = (-x)+(2*y)+(3*z)
z1 = (5*x)+y+(-2*z)

print(x1,y1,z1)
# Out:
# 26 20 9

# %%
tm1 = ([[4,1,2],[-1,2,3],[5,1,-2]])
tm1 = np.array(tm1)
tm1.T
# Out:
# array([[ 4, -1,  5],
#        [ 1,  2,  1],
#        [ 2,  3, -2]])

# %%
abc1 = np.dot(b_inp_matrix, tm1.T)
print(b_inp_matrix.shape, tm1.T.shape)
abc1
# Out:
# (3,) (3, 3)
# array([26, 20,  9])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %%
# Eigenvalues -

# %%
# Eigenvectors -

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %%
# Sence of space is distorted
# The cost of running through processing power 
#   takes a lot of time, and resources

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %%
# The rule of thumbs is to have 5 times the rows for each column.
# If I had 5 columns, I would need 25 rows. 
# The high risk of overfitting comes as a result of 
# 1 column to 5 row ratio

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
# center each column by subtracting its mean from each componet
# Z-matrix - devide each col by it's std

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head()
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION  ...  FMTASSISTED  FMTBURDEN  FMTREGION  FMTSTATUS
# 0        0    82       2       0  ...            0          2          0          0
# 1        1    50       4       2  ...            0          1          0          0
# 2        2    53       4       2  ...            0          3          0          0
# 3        3    67       4       2  ...            0          1          0          0
# 4        4    26       0       2  ...            1          1          0          0
#
# [5 rows x 99 columns]

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
### Your Code Here

# %%
from numpy import array
from numpy import mean
from numpy import std
from numpy import cov
from numpy.linalg import eig
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Define a matrix
# X = array([[1,2],[3,4],[5,6]])
X = national_processed
print('Data: \n',X)
# Out:
# Data:
#         CONTROL  AGE1  METRO3  ...  FMTBURDEN  FMTREGION  FMTSTATUS
# 0            0    82       2  ...          2          0          0
# 1            1    50       4  ...          1          0          0
# 2            2    53       4  ...          3          0          0
# 3            3    67       4  ...          1          0          0
# 4            4    26       0  ...          1          0          0
# ...        ...   ...     ...  ...        ...        ...        ...
# 64530    64530    55       0  ...          3          1          0
# 64531    64531    37       0  ...          1          0          0
# 64532    64532    23       1  ...          3          1          0
# 64533    64533    57       0  ...          1          1          0
# 64534    64534    66       3  ...          1          0          0
#
# [64535 rows x 99 columns]

# %%
X['FMTSTATUS'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: FMTSTATUS, dtype: int8

# %%
X = X.drop(columns='FMTSTATUS')
X
# Out:
#        CONTROL  AGE1  METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0            0    82       2  ...            0          2          0
# 1            1    50       4  ...            0          1          0
# 2            2    53       4  ...            0          3          0
# 3            3    67       4  ...            0          1          0
# 4            4    26       0  ...            1          1          0
# ...        ...   ...     ...  ...          ...        ...        ...
# 64530    64530    55       0  ...            1          3          1
# 64531    64531    37       0  ...            1          1          0
# 64532    64532    23       1  ...            1          3          1
# 64533    64533    57       0  ...            1          1          1
# 64534    64534    66       3  ...            1          1          0
#
# [64535 rows x 98 columns]

# %%
# Caluclate the means from each column
means = mean(X.T, axis=1)
print('\nMeans:\n',means)
# Out:
# Means:
#  CONTROL                32267.000000
# AGE1                      47.968932
# METRO3                     1.227179
# REGION                     1.394406
# LMED                   68109.744309
#                            ...
# FMTCOSTMEDRELAMICAT        2.770900
# FMTINCRELAMICAT            3.996715
# FMTASSISTED                0.478237
# FMTBURDEN                  1.497823
# FMTREGION                  0.175967
# Length: 98, dtype: float64

# %%
# Center columns by subtracting column means ---- 
centered_data = X-means
# print centered data
print('\nCentered Data:\n',centered_data)
# Out:
# Centered Data:
#         CONTROL       AGE1    METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0     -32267.0  34.031068  0.772821  ...    -0.478237   0.502177  -0.175967
# 1     -32266.0   2.031068  2.772821  ...    -0.478237  -0.497823  -0.175967
# 2     -32265.0   5.031068  2.772821  ...    -0.478237   1.502177  -0.175967
# 3     -32264.0  19.031068  2.772821  ...    -0.478237  -0.497823  -0.175967
# 4     -32263.0 -21.968932 -1.227179  ...     0.521763  -0.497823  -0.175967
# ...        ...        ...       ...  ...          ...        ...        ...
# 64530  32263.0   7.031068 -1.227179  ...     0.521763   1.502177   0.824033
# 64531  32264.0 -10.968932 -1.227179  ...     0.521763  -0.497823  -0.175967
# 64532  32265.0 -24.968932 -0.227179  ...     0.521763   1.502177   0.824033
# 64533  32266.0   9.031068 -1.227179  ...     0.521763  -0.497823   0.824033
# 64534  32267.0  18.031068  1.772821  ...     0.521763  -0.497823  -0.175967
#
# [64535 rows x 98 columns]

# %%
# Standard deviation of each column
std_devs = std(X.T, axis=1)
print('\nStandard Deviations:\n',std_devs)
# Out:
# Standard Deviations:
#  CONTROL                18629.649809
# AGE1                      22.869197
# METRO3                     1.269450
# REGION                     1.050106
# LMED                   12371.081326
#                            ...
# FMTCOSTMEDRELAMICAT        1.975247
# FMTINCRELAMICAT            2.562785
# FMTASSISTED                0.674258
# FMTBURDEN                  0.913925
# FMTREGION                  0.380792
# Length: 98, dtype: float64

# %%
# Complete the standardization by dividing by std_devs
standardized_data = centered_data / std_devs
print('\nStandardized data:\n',standardized_data)
# Out:
# Standardized data:
#          CONTROL      AGE1    METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0     -1.732024  1.488075  0.608784  ...    -0.709278   0.549473  -0.462107
# 1     -1.731970  0.088812  2.184270  ...    -0.709278  -0.544709  -0.462107
# 2     -1.731917  0.219993  2.184270  ...    -0.709278   1.643655  -0.462107
# 3     -1.731863  0.832170  2.184270  ...    -0.709278  -0.544709  -0.462107
# 4     -1.731809 -0.960634 -0.966702  ...     0.773833  -0.544709  -0.462107
# ...         ...       ...       ...  ...          ...        ...        ...
# 64530  1.731809  0.307447 -0.966702  ...     0.773833   1.643655   2.164001
# 64531  1.731863 -0.479638 -0.966702  ...     0.773833  -0.544709  -0.462107
# 64532  1.731917 -1.091815 -0.178959  ...     0.773833   1.643655   2.164001
# 64533  1.731970  0.394901 -0.966702  ...     0.773833  -0.544709   2.164001
# 64534  1.732024  0.788443  1.396527  ...     0.773833  -0.544709  -0.462107
#
# [64535 rows x 98 columns]

# %%
# # standardize columns
# standardized_data = centered_data / std_devs
# standardized_data['FMTSTATUS'] = standardized_data['FMTSTATUS'].fillna(0)

# %%
# Calculate the COVARIANCE matrix of our standardized matrix
cov_matrix = cov(standardized_data.T)
print('\nCovariance Matrix:\n',cov_matrix)
# Out:
# Covariance Matrix:
#  [[ 1.0000155   0.01075555  0.02227271 ...  0.19469617  0.0236342
#    0.01775892]
#  [ 0.01075555  1.0000155   0.07690262 ...  0.01147914  0.3103764
#   -0.00355557]
#  [ 0.02227271  0.07690262  1.0000155  ... -0.19744768 -0.08677012
#   -0.05644554]
#  ...
#  [ 0.19469617  0.01147914 -0.19744768 ...  1.0000155   0.2796445
#    0.03241822]
#  [ 0.0236342   0.3103764  -0.08677012 ...  0.2796445   1.0000155
#    0.02305213]
#  [ 0.01775892 -0.00355557 -0.05644554 ...  0.03241822  0.02305213
#    1.0000155 ]]

# %%
# Eigendecomposition of covariance matrix
values, vectors = eig(cov_matrix)
print('\n Eigenvectors: \n', vectors)
print('\n Eigenvalues: \n', values)
# Out:
#  Eigenvectors:
#  [[ 1.76229366e-02+0.00000000e+00j  2.32268483e-03+0.00000000e+00j
#   -7.97725679e-03+0.00000000e+00j ...  5.77412138e-15-5.77917831e-15j
#    5.77412138e-15+5.77917831e-15j  1.77595658e-14+0.00000000e+00j]
#  [-4.56417195e-02+0.00000000e+00j  1.28819739e-01+0.00000000e+00j
#   -8.98875854e-02+0.00000000e+00j ... -1.20423599e-14+7.07053030e-15j
#   -1.20423599e-14-7.07053030e-15j -7.79679178e-14+0.00000000e+00j]
#  [-2.24448253e-03+0.00000000e+00j -2.78724815e-02+0.00000000e+00j
#   -1.19950423e-01+0.00000000e+00j ... -6.43977236e-15+1.27523966e-14j
#   -6.43977236e-15-1.27523966e-14j -9.75359109e-14+0.00000000e+00j]
#  ...
#  [ 8.54117227e-02+0.00000000e+00j  9.53459192e-02+0.00000000e+00j
#    2.08533678e-02+0.00000000e+00j ... -4.24112925e-14+1.80334123e-14j
#   -4.24112925e-14-1.80334123e-14j -2.13963878e-13+0.00000000e+00j]
#  [-3.20621959e-03+0.00000000e+00j  9.24956691e-02+0.00000000e+00j
# ...

# %%
P = vectors.T.dot(standardized_data.T)
print('\nProjected data:\n', P.T)
# Out:
# Projected data:
#  [[ 2.57657018e+00+0.00000000e+00j  1.37612732e+00+0.00000000e+00j
#   -1.25383508e+00+0.00000000e+00j ... -1.77710235e-13-3.14865644e-14j
#   -1.77710235e-13+3.14865644e-14j -6.37722287e-13+0.00000000e+00j]
#  [-2.04064284e+00+0.00000000e+00j  9.88061441e-01+0.00000000e+00j
#   -2.23799949e+00+0.00000000e+00j ... -2.57002058e-14+8.09385565e-13j
#   -2.57002058e-14-8.09385565e-13j  5.25105770e-12+0.00000000e+00j]
#  [-1.21527025e+00+0.00000000e+00j -3.70168163e-01+0.00000000e+00j
#   -3.24860582e+00+0.00000000e+00j ... -2.94573838e-12+9.66052218e-13j
#   -2.94573838e-12-9.66052218e-13j -1.95729048e-11+0.00000000e+00j]
#  ...
#  [-1.83162816e+00+0.00000000e+00j  2.95570213e+00+0.00000000e+00j
#    5.28543479e+00+0.00000000e+00j ... -1.21179589e-13-4.53529332e-14j
#   -1.21179589e-13+4.53529332e-14j  7.64301363e-14+0.00000000e+00j]
#  [ 5.02514474e+00+0.00000000e+00j  2.52857814e+00+0.00000000e+00j
# ...

# %%
pca = PCA(98)
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=98, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.fit_transform(X)
# Out:
# array([[-1.11233045e+05, -4.33894279e+04, -5.27826002e+03, ...,
#         -1.20798978e-10, -3.07062109e-10, -9.19950259e-12],
#        [ 4.62665514e+03,  9.80906149e+04,  1.36028377e+04, ...,
#         -1.68547790e-11, -1.98392598e-10,  3.60969364e-12],
#        [ 5.17600358e+02, -3.87034993e+04,  1.53799864e+04, ...,
#          1.16109955e-10,  2.00614492e-10,  8.91263990e-12],
#        ...,
#        [-1.40697009e+05,  1.14881707e+04, -5.73987043e+04, ...,
#          2.52831639e-12, -1.95144049e-11, -1.00249770e-11],
#        [-1.38745450e+05,  3.36362534e+04, -2.39057709e+03, ...,
#          7.21643235e-13, -1.97606427e-11, -8.47059669e-13],
#        [-1.53894773e+05, -4.42445857e+04,  4.76898069e+04, ...,
#         -1.09750543e-11, -1.39324225e-11, -7.51967463e-13]])

# %%
print(pca.explained_variance_ratio_)
# Out:
# [8.67140659e-01 9.92026141e-02 1.31042380e-02 1.00342766e-02
#  4.70218612e-03 3.16405892e-03 1.33998015e-03 1.05833980e-03
#  1.46442454e-04 4.34133012e-05 2.05731157e-05 1.82800410e-05
#  1.71684125e-05 4.36864451e-06 1.52473580e-06 6.49018173e-07
#  3.17922578e-07 2.38284621e-07 1.82592904e-07 1.53881643e-07
#  1.38365544e-07 9.45090140e-08 3.44948257e-08 1.94907252e-08
#  1.25564924e-08 1.01977706e-08 8.74345277e-09 7.87949848e-09
#  3.96502034e-09 2.91468445e-09 1.00029615e-09 2.66360411e-10
#  1.06149799e-10 8.94048765e-11 7.22937842e-11 6.12165810e-11
#  4.36998233e-11 2.99304094e-11 1.58170316e-11 1.09025416e-11
#  9.51825195e-12 9.33346663e-12 8.03333485e-12 5.59687534e-12
#  4.76317909e-12 3.01729948e-12 2.61162373e-12 2.40982661e-12
#  2.35006758e-12 1.88527684e-12 1.63545118e-12 1.53194266e-12
#  1.28547526e-12 1.16720679e-12 1.11638074e-12 9.86430218e-13
#  8.55670943e-13 7.02687813e-13 5.27401527e-13 5.06000806e-13
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
ax = plt.scatter(pca.components_[0], pca.components_[1])

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
