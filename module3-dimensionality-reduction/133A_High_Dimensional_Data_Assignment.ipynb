# %% [markdown]
# <a href="https://colab.research.google.com/github/jdblackstar/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/module3-dimensionality-reduction/133A_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
# imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from math import pi, sin, cos

# %%
# a standard quadratic graph passes the vertical line test

x = np.linspace(-10,10,1000)
y = 2*x**2 - 1

plt.plot(x,y, color = 'blue')
plt.show()

# %%
# same graph with x and y swapped

y = np.linspace(-10,10,1000)
x = 2*y**2 - 1

plt.plot(x,y, color = 'blue')
plt.show()

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# Because you get multiple y-values for any inputted x-value.

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %% [markdown]
# Relation 2 is the only relation that is a function, because each y-value is associated with one unique x-value

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %% [markdown]
# m: 3d, codomain: 3d
# n: 4d, codomain: 2d

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %% [markdown]
# Sure, if a function can pull a Matthew McConaughey and travel through a wormhole and just so happens to land in another dimension.

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %% [markdown]
# \begin{align}
# \text{hats: }
# \begin{bmatrix} 1 \\ 0 \end{bmatrix}\hat{i} + \begin{bmatrix} 0 \\ 1 \end{bmatrix}\hat{j}
# \\
# \\
# T(p) = \begin{bmatrix} 1 + 3(0) \\ -1 + 2(0) \end{bmatrix}\hat{i} + \begin{bmatrix} 0 + 3(1) \\ -(0) + 2(1) \end{bmatrix}\hat{j} = \begin{bmatrix} 1 \ \ \ 3 \\ -1 \ \ \ 2\end{bmatrix}
# \\
# \\
# \text{Reorganized p-matrix: }\begin{bmatrix} 1 & 3 \\ -1 & 2 \end{bmatrix}
# \end{align}

# %% [markdown]
# \begin{align}
# \text{hats: }
# \begin{bmatrix} 1 \\ 0 \\ 0 \end{bmatrix}\hat{i} + \begin{bmatrix} 0 \\ 1 \\ 0 \end{bmatrix}\hat{j} +
# \begin{bmatrix} 0 \\ 0 \\ 1 \end{bmatrix}\hat{k}
# \\
# \\
# T(q) = \begin{bmatrix} 4 + 1 + 2 \\ -1 + 2 + 3 \\ 5 + 1 - 2 \end{bmatrix}\hat{i} + \begin{bmatrix} 4 + 1 + 2 \\ -1 + 2 + 3 \\ 5 + 1 - 2 \end{bmatrix}\hat{j} + \begin{bmatrix} 4 + 1 + 2 \\ -1 + 2 + 3 \\ 5 + 1 - 2 \end{bmatrix}\hat{k}= \begin{bmatrix} 4 \ \ \ 1 \ \ \ 2 \\ -1 \ \ \ 2 \ \ \ 3 \\ 5 \ \ \ 1 \ \ \ -2\end{bmatrix}
# \\
# \\
# \text{Reorganized q-matrix: }\begin{bmatrix} 4 & 1 & 2 \\ -1 & 2 & 3 \\ 5 & 1 & -2 \end{bmatrix}
# \end{align}

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
def p(x1, x2):
  y1 = 1*x1 + 3 * x2
  y2 = -1 * x1 + 2 * x2
  return y1, y2

def q(x1,x2,x3):
  y1 = 4*x1 + x2 + 2*x3
  y2 = -x1 + 2*x2 + 3*x3
  y3 = 5*x1 + x2 - 2*x3
  return y1, y2, y3

# %%
p(1, 2)
# Out:
# (7, 3)

# %%
q(-1, 2 ,4)
# Out:
# (6, 17, -11)

# %%
p_input = np.array([[1],
               [2]])
p_trans = np.array([[1, 3],
                    [-1, 2]])
np.matmul(p_trans, p_input)
# Out:
# array([[7],
#        [3]])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %% [markdown]
# An Eigenvector is the vector which best fits all of the data, weighted by the variance of the variables we have. Variables with a larger variance will have more say in the eigenvector's direction / location and will have small eigenvalues. An eigenvalue is a scalar which represents the amount a vector is stretched or shrunk when being normalized onto the eigenvector.) A low eigenvalue means a low stretch, and higher variance in that variable (and more effect on eigenvector). A high eigenvalue means a high stretch, and lower variance in that variable (lesser effect on eigenvector.)

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %% [markdown]
# The biggest challenge when working with high dimensional spaces is the risk of overfitting our data. An example of this would be, for instace, taking a measure of every new case of coronavirus every hour. That's super accurate, but you may go 2 or 3 hours without any new cases. It would be much more effective to take daily totals instead.

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %% [markdown]
# 5 times the number of observatrions as the number of parameters.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head()
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION  ...  FMTASSISTED  FMTBURDEN  FMTREGION  FMTSTATUS
# 0        0    82       2       0  ...            0          2          0          0
# 1        1    50       4       2  ...            0          1          0          0
# 2        2    53       4       2  ...            0          3          0          0
# 3        3    67       4       2  ...            0          1          0          0
# 4        4    26       0       2  ...            1          1          0          0
#
# [5 rows x 99 columns]

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
# imports

from numpy import array
from numpy import mean
from numpy import std
from numpy import cov
from numpy.linalg import eig

# %%
# drop the FMTSTATUS column

national_processed = national_processed.drop(['FMTSTATUS'], axis=1)
national_processed.head()
# Out:
#    CONTROL  AGE1  METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0        0    82       2  ...            0          2          0
# 1        1    50       4  ...            0          1          0
# 2        2    53       4  ...            0          3          0
# 3        3    67       4  ...            0          1          0
# 4        4    26       0  ...            1          1          0
#
# [5 rows x 98 columns]

# %%
# find the means

means = mean(national_processed.T, axis=1)
means
# Out:
# CONTROL                32267.000000
# AGE1                      47.968932
# METRO3                     1.227179
# REGION                     1.394406
# LMED                   68109.744309
#                            ...
# FMTCOSTMEDRELAMICAT        2.770900
# FMTINCRELAMICAT            3.996715
# FMTASSISTED                0.478237
# FMTBURDEN                  1.497823
# FMTREGION                  0.175967
# Length: 98, dtype: float64

# %%
# center data around 0 by subtracting mean from each value in columns

center_data = national_processed - means
center_data.head()
# Out:
#    CONTROL       AGE1    METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0 -32267.0  34.031068  0.772821  ...    -0.478237   0.502177  -0.175967
# 1 -32266.0   2.031068  2.772821  ...    -0.478237  -0.497823  -0.175967
# 2 -32265.0   5.031068  2.772821  ...    -0.478237   1.502177  -0.175967
# 3 -32264.0  19.031068  2.772821  ...    -0.478237  -0.497823  -0.175967
# 4 -32263.0 -21.968932 -1.227179  ...     0.521763  -0.497823  -0.175967
#
# [5 rows x 98 columns]

# %%
# std for each column

stdev = std(national_processed.T, axis = 1)
stdev
# Out:
# CONTROL                18629.649809
# AGE1                      22.869197
# METRO3                     1.269450
# REGION                     1.050106
# LMED                   12371.081326
#                            ...
# FMTCOSTMEDRELAMICAT        1.975247
# FMTINCRELAMICAT            2.562785
# FMTASSISTED                0.674258
# FMTBURDEN                  0.913925
# FMTREGION                  0.380792
# Length: 98, dtype: float64

# %%
# standardized data is the centered data over its deviation

standard_data = center_data / stdev
standard_data.head()
# Out:
#     CONTROL      AGE1    METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0 -1.732024  1.488075  0.608784  ...    -0.709278   0.549473  -0.462107
# 1 -1.731970  0.088812  2.184270  ...    -0.709278  -0.544709  -0.462107
# 2 -1.731917  0.219993  2.184270  ...    -0.709278   1.643655  -0.462107
# 3 -1.731863  0.832170  2.184270  ...    -0.709278  -0.544709  -0.462107
# 4 -1.731809 -0.960634 -0.966702  ...     0.773833  -0.544709  -0.462107
#
# [5 rows x 98 columns]

# %%
# make oue covariance matrix of the standard data

cov_matrix = cov(standard_data.T)
cov_matrix
# Out:
# array([[ 1.0000155 ,  0.01075555,  0.02227271, ...,  0.19469617,
#          0.0236342 ,  0.01775892],
#        [ 0.01075555,  1.0000155 ,  0.07690262, ...,  0.01147914,
#          0.3103764 , -0.00355557],
#        [ 0.02227271,  0.07690262,  1.0000155 , ..., -0.19744768,
#         -0.08677012, -0.05644554],
#        ...,
#        [ 0.19469617,  0.01147914, -0.19744768, ...,  1.0000155 ,
#          0.2796445 ,  0.03241822],
#        [ 0.0236342 ,  0.3103764 , -0.08677012, ...,  0.2796445 ,
#          1.0000155 ,  0.02305213],
#        [ 0.01775892, -0.00355557, -0.05644554, ...,  0.03241822,
#          0.02305213,  1.0000155 ]])

# %%
values, vectors = eig(cov_matrix)
values
# Out:
# array([ 3.33700479e+01+0.00000000e+00j,  1.41535396e+01+0.00000000e+00j,
#         1.00820202e+01+0.00000000e+00j,  7.10060309e+00+0.00000000e+00j,
#         5.06332832e+00+0.00000000e+00j,  3.92661817e+00+0.00000000e+00j,
#         2.73018834e+00+0.00000000e+00j,  2.17601958e+00+0.00000000e+00j,
#         1.97661216e+00+0.00000000e+00j,  1.73476956e+00+0.00000000e+00j,
#         1.42372870e+00+0.00000000e+00j,  1.27352267e+00+0.00000000e+00j,
#         1.13247716e+00+0.00000000e+00j,  1.03636584e+00+0.00000000e+00j,
#         1.01164141e+00+0.00000000e+00j,  9.81080825e-01+0.00000000e+00j,
#         8.92864095e-01+0.00000000e+00j,  8.02160726e-01+0.00000000e+00j,
#         7.27567619e-01+0.00000000e+00j,  6.58980016e-01+0.00000000e+00j,
#         6.08965274e-01+0.00000000e+00j,  5.69166303e-01+0.00000000e+00j,
#         5.34098152e-01+0.00000000e+00j,  4.43810518e-01+0.00000000e+00j,
#         4.68081210e-01+0.00000000e+00j,  3.25185974e-01+0.00000000e+00j,
# ...

# %%
vectors
# Out:
# array([[ 1.76229366e-02+0.00000000e+00j,  2.32268483e-03+0.00000000e+00j,
#         -7.97725679e-03+0.00000000e+00j, ...,
#          5.77412138e-15-5.77917831e-15j,  5.77412138e-15+5.77917831e-15j,
#          1.77595658e-14+0.00000000e+00j],
#        [-4.56417195e-02+0.00000000e+00j,  1.28819739e-01+0.00000000e+00j,
#         -8.98875854e-02+0.00000000e+00j, ...,
#         -1.20423599e-14+7.07053030e-15j, -1.20423599e-14-7.07053030e-15j,
#         -7.79679178e-14+0.00000000e+00j],
#        [-2.24448253e-03+0.00000000e+00j, -2.78724815e-02+0.00000000e+00j,
#         -1.19950423e-01+0.00000000e+00j, ...,
#         -6.43977236e-15+1.27523966e-14j, -6.43977236e-15-1.27523966e-14j,
#         -9.75359109e-14+0.00000000e+00j],
#        ...,
#        [ 8.54117227e-02+0.00000000e+00j,  9.53459192e-02+0.00000000e+00j,
#          2.08533678e-02+0.00000000e+00j, ...,
#         -4.24112925e-14+1.80334123e-14j, -4.24112925e-14-1.80334123e-14j,
#         -2.13963878e-13+0.00000000e+00j],
# ...

# %%
projected = vectors.T.dot(standard_data.T)
projected
# Out:
# array([[ 2.57657018e+00+0.00000000e+00j, -2.04064284e+00+0.00000000e+00j,
#         -1.21527025e+00+0.00000000e+00j, ...,
#         -1.83162816e+00+0.00000000e+00j,  5.02514474e+00+0.00000000e+00j,
#          9.89816404e+00+0.00000000e+00j],
#        [ 1.37612732e+00+0.00000000e+00j,  9.88061441e-01+0.00000000e+00j,
#         -3.70168163e-01+0.00000000e+00j, ...,
#          2.95570213e+00+0.00000000e+00j,  2.52857814e+00+0.00000000e+00j,
#          8.02842666e-01+0.00000000e+00j],
#        [-1.25383508e+00+0.00000000e+00j, -2.23799949e+00+0.00000000e+00j,
#         -3.24860582e+00+0.00000000e+00j, ...,
#          5.28543479e+00+0.00000000e+00j, -1.02019576e-01+0.00000000e+00j,
#         -3.53506324e+00+0.00000000e+00j],
#        ...,
#        [-1.77710235e-13-3.14865644e-14j, -2.57002058e-14+8.09385565e-13j,
#         -2.94573838e-12+9.66052218e-13j, ...,
#         -1.21179589e-13-4.53529332e-14j,  1.03518762e-14-1.62879706e-14j,
#          1.19366462e-14-3.67438208e-14j],
# ...

# %%
# PCA time
from numpy import array
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# create matrix X
X = national_processed
print("Data: \n", X)

# make scaler object to fit our data
scaler = StandardScaler()
Z = scaler.fit_transform(X)
print("\n Standardized Data: \n", Z)

# PCA instance -> fit PCA on data
pca = PCA(2)
pca.fit(Z)

print("\n Eigenvectors: \n", pca.components_)
print("\n Eigenvalues: \n",pca.explained_variance_)

# transform
B = pca.transform(Z)
print("\n Projected Data: \n", B)
# Out:
# Data:
#         CONTROL  AGE1  METRO3  ...  FMTASSISTED  FMTBURDEN  FMTREGION
# 0            0    82       2  ...            0          2          0
# 1            1    50       4  ...            0          1          0
# 2            2    53       4  ...            0          3          0
# 3            3    67       4  ...            0          1          0
# 4            4    26       0  ...            1          1          0
# ...        ...   ...     ...  ...          ...        ...        ...
# 64530    64530    55       0  ...            1          3          1
# 64531    64531    37       0  ...            1          1          0
# 64532    64532    23       1  ...            1          3          1
# 64533    64533    57       0  ...            1          1          1
# 64534    64534    66       3  ...            1          1          0
#
# [64535 rows x 98 columns]
#
#  Standardized Data:
#  [[-1.73202397  1.48807451  0.60878419 ... -0.70927797  0.54947295
# ...

# %%
R = pd.DataFrame(B)
R.head()
# Out:
#           0         1
# 0 -2.576570 -1.376127
# 1  2.040643 -0.988061
# 2  1.215270  0.370168
# 3  2.821837  1.723711
# 4 -1.570106 -0.878362

# %%
plt.scatter(R[0], R[1])
plt.title('Housing Data PCA(2)', color='w')
plt.xlim(-20,40)
plt.ylim(-20,40)
plt.xlabel('PC1', color='w')
plt.ylabel('PC2', color='w')
plt.show()

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
